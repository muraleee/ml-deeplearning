# %% [markdown]
# <a href="https://colab.research.google.com/github/muraleee/ml-deeplearning/blob/main/wk02/DL-ML-Wk02-01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls -al
# Out:
# total 20
# drwxr-xr-x 1 root root 4096 May 10 22:01 .
# drwxr-xr-x 1 root root 4096 May 10 20:35 ..
# drwxr-xr-x 4 root root 4096 May  6 13:29 .config
# drwxr-xr-x 5 root root 4096 May 10 22:01 ml-deeplearning
# drwxr-xr-x 1 root root 4096 May  6 13:29 sample_data

# %%
import os
os.chdir('/content/ml-deeplearning/wk01')
import math, copy
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append('.') # Add current directory to path
plt.style.use('./deeplearning.mplstyle')
from lab_utils_uni import plt_house_x, plt_contour_wgrad, plt_divergence
